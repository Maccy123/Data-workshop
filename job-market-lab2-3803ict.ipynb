# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Load job market
job = pd.read_csv('job-market(2).csv')
job.head()
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330.0                              Team member - Belrose
# 4  37404308.0  Business Banking Contact Centre Specialist, Ni...
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 2                             LB Creative Pty Ltd  2018-10-07T00:00:00.000Z
# 3                          Anaconda Group Pty Ltd  2018-10-07T00:00:00.000Z
# 4  Commonwealth Bank - Business & Private Banking  2018-10-07T00:00:00.000Z
#
#                   Location                         Area  \
# 0                   Sydney  North West & Hills District
# ...

# %%
# %matplotlib inline

sns.barplot(job, x="HighestSalary", y="Classification", saturation=10, dodge = 10)
# Out:
# <Axes: xlabel='HighestSalary', ylabel='Classification'>

# %%
import matplotlib
#create dataframe for salary ranges

job['salary ranges'] = job['HighestSalary'] - job['LowestSalary']
job.head()
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330.0                              Team member - Belrose
# 4  37404308.0  Business Banking Contact Centre Specialist, Ni...
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 2                             LB Creative Pty Ltd  2018-10-07T00:00:00.000Z
# 3                          Anaconda Group Pty Ltd  2018-10-07T00:00:00.000Z
# 4  Commonwealth Bank - Business & Private Banking  2018-10-07T00:00:00.000Z
#
#                   Location                         Area  \
# 0                   Sydney  North West & Hills District
# ...

# %%
salary = job['salary ranges']
  
# plotting data on chart 
plt.pie(salary, labels='lowest salary', colors='bright', autopct='%.0f%%') 
  
# displaying chart 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 4
#       1 salary = job['salary ranges']
#       3 # plotting data on chart
# ----> 4 plt.pie(salary, labels='lowest salary', colors='bright', autopct='%.0f%%')
#       6 # displaying chart
#       7 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3546, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3523 @_copy_docstring_and_deprecators(Axes.pie)
#    3524 def pie(
#    3525     x: ArrayLike,
#    (...)
#    3544     data=None,
#    3545 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3546     return gca().pie(
#    3547         x,
#    3548         explode=explode,
#    3549         labels=labels,
# ...

# %%
locationDf = df[df['Location'].isna()==False]
locationDf = locationDf.groupby('Location').count()
locationDf['Location'] = locationDf.index
locationDf['Count'] = locationDf["Id"]
locationDf.head()
# Out:
#                            Id  Title  Company  Date  Area  Classification  \
# Location
# ACT                       238    238      235   238     0             238
# Adelaide                  390    390      356   390     0             390
# Adelaide Hills & Barossa   19     19       18    19     0              19
# Albany & Great Southern    10     10       10    10     0              10
# Albury Area                19     19       18    19     0              19
#
#                           SubClassification  Requirement  FullDescription  \
# Location
# ACT                                     238          238              235
# Adelaide                                390          390              374
# Adelaide Hills & Barossa                 19           19               19
# Albany & Great Southern                  10           10               10
# Albury Area                              19           19               19
#
# ...

# %%
# %matplotlib inline
# Pie char for job market share of cities
from matplotlib import cm
# Out:
# Text(50.0, 0.5, '')
